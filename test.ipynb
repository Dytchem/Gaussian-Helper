# %%
from opt_helper.opt_in import opt_in
from opt_helper.opt_out import opt_out
from Molecule import Molecule

# %%
a = opt_in("./opt_helper/data/a.in")
print(a.get_full_content())
# Out:
# %nprocshared=5
# %mem=5GB
# %chk=/data/huangdeqing/azm/QM/nn/S0_cis/chk/+40.chk
# #p opt=(calcfc,MaxStep=40,tight,gdiis) freq=(HPModes,SaveNormalModes) scf=tight Pop=Full casscf(6,4)/6-31+g(d) geom=connectivity nosymm field=y+40
#
# S0_cis_nn_+40
#
# 0 1
# N  -0.60217709   -0.03579554   1.28527700
# N  0.63769791   -0.03579554   1.28527700
# C  1.37949802   0.01003466   0.02225100
# H  2.42943915   0.06405512   0.26826000
# H  1.20030085   -0.89042390   -0.55795100
# H  1.11690211   0.87236630   -0.57941600
# C  -1.34397798   0.01003225   0.02225200
# H  -1.08139489   0.87237362   -0.57940800
# H  -1.16476815   -0.89041818   -0.55795800
# H  -2.39391985   0.06403679   0.26826200
#
#  1 2 2.0 7 1.0
#  2 3 1.0
#  3 4 1.0 5 1.0 6 1.0
#  4
#  5
#  6
#  7 8 1.0 9 1.0 10 1.0
#  8
#  9
#  10

# %%
a.update_max_step(50)
print(a.get_full_content())
a.save_to_file("./opt_helper/data/a_modified.in")
# Out:
# %nprocshared=5
# %mem=5GB
# %chk=/data/huangdeqing/azm/QM/nn/S0_cis/chk/+40.chk
# #p opt=(calcfc,MaxStep=50,tight,gdiis) freq=(HPModes,SaveNormalModes) scf=tight Pop=Full casscf(6,4)/6-31+g(d) geom=connectivity nosymm field=y+40
#
# S0_cis_nn_+40
#
# 0 1
# N  -0.60217709   -0.03579554   1.28527700
# N  0.63769791   -0.03579554   1.28527700
# C  1.37949802   0.01003466   0.02225100
# H  2.42943915   0.06405512   0.26826000
# H  1.20030085   -0.89042390   -0.55795100
# H  1.11690211   0.87236630   -0.57941600
# C  -1.34397798   0.01003225   0.02225200
# H  -1.08139489   0.87237362   -0.57940800
# H  -1.16476815   -0.89041818   -0.55795800
# H  -2.39391985   0.06403679   0.26826200
#
#  1 2 2.0 7 1.0
#  2 3 1.0
#  3 4 1.0 5 1.0 6 1.0
#  4
#  5
#  6
#  7 8 1.0 9 1.0 10 1.0
#  8
#  9
#  10

# %%
print(a.molecule.to_string())
# Out:
# N  -0.60217709   -0.03579554   1.28527700
# N  0.63769791   -0.03579554   1.28527700
# C  1.37949802   0.01003466   0.02225100
# H  2.42943915   0.06405512   0.26826000
# H  1.20030085   -0.89042390   -0.55795100
# H  1.11690211   0.87236630   -0.57941600
# C  -1.34397798   0.01003225   0.02225200
# H  -1.08139489   0.87237362   -0.57940800
# H  -1.16476815   -0.89041818   -0.55795800
# H  -2.39391985   0.06403679   0.26826200

# %%
b=opt_out("./opt_helper/data/a_normal.out")
c=opt_out("./opt_helper/data/a_error.out")
print(b.is_normal(),c.is_normal())  # True False
print(b.get_first_frequency_info())
print(c.get_first_frequency_info())  # None
print(b.final_molecule.to_string())
print(c.final_molecule.to_string())
# Out:
# True False
# (-39.471, '0.00  -0.01   0.00\n0.00  0.01   0.00\n0.00  0.04   0.00\n-0.02  -0.33   0.00\n-0.25  0.27   -0.23\n0.29  0.25   0.23\n0.00  -0.04   0.00\n0.29  -0.25   -0.23\n-0.25  -0.27   0.23\n-0.02  0.33   0.00')
# (None, None)
# -0.602177   0.042779   1.285312
# 0.637698   0.042781   1.285312
# 1.379498   -0.001877   0.022245
# 2.429439   -0.056113   0.268206
# 1.116912   -0.863658   -0.580215
# 1.200292   0.899115   -0.557127
# -1.343978   -0.001883   0.022246
# -1.164776   0.899108   -0.557128
# -1.081389   -0.863664   -0.580213
# -2.393919   -0.056123   0.268208
# -0.599289   -0.687060   1.085376
# 0.638445   -0.740212   1.051468
# 1.382122   -0.070820   -0.018668
# 2.418291   -0.356579   0.083946
# 1.036085   -0.350466   -1.007166
# 1.304932   1.007381   0.089549
# -1.339110   0.042859   0.052523
# -1.057050   1.091497   0.035449
# -1.177866   -0.380613   -0.932719
# -2.388334   -0.035077   0.295562

# %%
print(a.molecule.to_string())
print()
# print(a.molecule.reframe(1,2,"y",3,"z").to_string())
print((a.molecule.reframe(1,2,"x",3,"y")).to_string())
# Out:
# N  -0.60217709   -0.04579554   1.28527700
# N  0.63769791   -0.02579554   1.28527700
# C  1.37949802   0.05003466   0.02225100
# H  2.40943915   -0.26594488   0.26826000
# H  0.95030085   -0.62042390   -0.78795100
# H  1.40690211   1.12236630   -0.34941600
# C  -1.34397798   -0.02996775   0.02225200
# H  -0.79139489   0.62237362   -0.80940800
# H  -1.41476815   -1.16041818   -0.32795800
# H  -2.41391985   0.39403679   0.26826200
#
# N  -0.60283738   0.02886693   1.28545916
# N  0.63719892   0.02886693   1.28545916
# C  1.38012557   0.02886693   0.02081996
# H  2.40483644   -0.29083689   0.28330679
# H  0.94017070   -0.67464579   -0.75484861
# H  1.42482126   1.08048316   -0.40448944
# C  -1.34428650   -0.00715327   0.02264208
# H  -0.78125396   0.59337672   -0.84044180
# H  -1.43330000   -1.15255790   -0.27010577
# H  -2.40725062   0.44591186   0.24606019

# %%
a.molecule=a.molecule+Molecule(b.get_first_frequency_info()[1])
print(a.molecule.to_string())
# Out:
# N  -0.60217709   -0.04579554   1.28527700
# N  0.63769791   -0.02579554   1.28527700
# C  1.37949802   0.05003466   0.02225100
# H  2.40943915   -0.26594488   0.26826000
# H  0.95030085   -0.62042390   -0.78795100
# H  1.40690211   1.12236630   -0.34941600
# C  -1.34397798   -0.02996775   0.02225200
# H  -0.79139489   0.62237362   -0.80940800
# H  -1.41476815   -1.16041818   -0.32795800
# H  -2.41391985   0.39403679   0.26826200
