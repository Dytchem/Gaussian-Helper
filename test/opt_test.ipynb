# %%
import sys
sys.path.append('..')
from opt_helper.* import *
from Molecule import Molecule

# %%
file_name="a"
in_file_root="./test/data/"
out_file_root="./test/data/"
epoch=5
update_coefficient=0.5

# %%
opt_in("/mnt/e/GitHub/Gaussian-Helper/test/data/a.in")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 opt_in("/mnt/e/GitHub/Gaussian-Helper/test/data/a.in")
#
# NameError: name 'opt_in' is not defined
